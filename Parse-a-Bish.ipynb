# %%
from json import loads
from pprint import pprint

endpoint = 'https://www.googleapis.com/qpxExpress/v1/trips/search?'
key = 'AIzaSyC7dMEaFOxQFS75rANJ-xOmRQQBAtnPGqQ'

flights = None

with open("response.json") as file:
    flights = loads(file.read())
    
pprint(flights['trips']['tripOption'])
# Out:
# [{'id': 'RW1jsVfPbCSQ1MkidjmaCV001',
#   'kind': 'qpxexpress#tripOption',
#   'pricing': [{'baseFareTotal': 'USD98.60',
#                'fare': [{'basisCode': 'TNR',
#                          'carrier': 'NK',
#                          'destination': 'ATL',
#                          'id': 'Aq3PJus84KSeYIgVb2DPTtmKplTxDtU8ajGTtp/I',
#                          'kind': 'qpxexpress#fareInfo',
#                          'origin': 'MSP'}],
#                'fareCalculation': 'MSP NK ATL Q24.18 Q4.65 69.77TNR USD 98.60 '
#                                   'END ZP MSP XT 7.40US 4.10ZP 5.60AY 4.50XF '
#                                   'MSP4.50',
#                'kind': 'qpxexpress#pricingInfo',
#                'latestTicketingTime': '2017-08-08T13:21-04:00',
#                'passengers': {'adultCount': 1,
#                               'kind': 'qpxexpress#passengerCounts'},
#                'ptc': 'ADT',
#                'saleFareTotal': 'USD98.60',
# ...

# %%
len(flights['trips']['tripOption'])
# Out:
# 62

# %%
pprint(flights['trips']['tripOption'][0])
# Out:
# {'id': 'RW1jsVfPbCSQ1MkidjmaCV001',
#  'kind': 'qpxexpress#tripOption',
#  'pricing': [{'baseFareTotal': 'USD98.60',
#               'fare': [{'basisCode': 'TNR',
#                         'carrier': 'NK',
#                         'destination': 'ATL',
#                         'id': 'Aq3PJus84KSeYIgVb2DPTtmKplTxDtU8ajGTtp/I',
#                         'kind': 'qpxexpress#fareInfo',
#                         'origin': 'MSP'}],
#               'fareCalculation': 'MSP NK ATL Q24.18 Q4.65 69.77TNR USD 98.60 '
#                                  'END ZP MSP XT 7.40US 4.10ZP 5.60AY 4.50XF '
#                                  'MSP4.50',
#               'kind': 'qpxexpress#pricingInfo',
#               'latestTicketingTime': '2017-08-08T13:21-04:00',
#               'passengers': {'adultCount': 1,
#                              'kind': 'qpxexpress#passengerCounts'},
#               'ptc': 'ADT',
#               'saleFareTotal': 'USD98.60',
#               'saleTaxTotal': 'USD21.60',
# ...

# %%
flights['trips']['tripOption'][0]['pricing'][0]['saleTotal']
# Out:
# 'USD120.20'

# %%
for trip in flights['trips']['tripOption']:
    print('KIND:\t', trip['kind'])
    for price in trip['pricing']: 
        print('\tprice:\t', price['saleTotal'])
# Out:
# KIND:	 qpxexpress#tripOption
# 	price:	 USD120.20
# KIND:	 qpxexpress#tripOption
# 	price:	 USD137.30
# KIND:	 qpxexpress#tripOption
# 	price:	 USD181.90
# KIND:	 qpxexpress#tripOption
# 	price:	 USD191.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD191.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD191.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD191.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD191.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD191.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD207.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD216.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD221.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD228.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD228.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD253.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD271.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD271.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD288.80
# KIND:	 qpxexpress#tripOption
# 	price:	 USD295.80
# ...
