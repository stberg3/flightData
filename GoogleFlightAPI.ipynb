# %%
endpoint = 'https://www.googleapis.com/qpxExpress/v1/trips/search?'
key = 'AIzaSyC7dMEaFOxQFS75rANJ-xOmRQQBAtnPGqQ'

# %% [markdown]
# #### First, some practice

# %%
from apiclient.discovery import build

service = build('qpxExpress', 'v1', developerKey=key)

# %%
import datetime, time

WEEK_IN_SECS = 7*24*60*60

t = int(time.time())
current = datetime.datetime.utcfromtimestamp(t)

print(WEEK_IN_SECS)
print(t, "=", current.date())

future = datetime.datetime.utcfromtimestamp(t+WEEK_IN_SECS)
print((t+WEEK_IN_SECS), "=", future.date())

weeks = 2
future = datetime.datetime.utcfromtimestamp(t+WEEK_IN_SECS*weeks)
print((t+WEEK_IN_SECS*weeks), "=", future.date())

weeks = 3
future = datetime.datetime.utcfromtimestamp(t+WEEK_IN_SECS*weeks)
print((t+WEEK_IN_SECS*weeks), "=", future.date())

weeks = 4
future = datetime.datetime.utcfromtimestamp(t+WEEK_IN_SECS*weeks)
print((t+WEEK_IN_SECS*weeks), "=", future.date())
# d = datetime.date(2017, 8, 8)
# d.fromordinal(time.time())
# Out:
# 604800
# 1502219953 = 2017-08-08
# 1502824753 = 2017-08-15
# 1503429553 = 2017-08-22
# 1504034353 = 2017-08-29
# 1504639153 = 2017-09-05

# %%
data = {
  "request": {
    "passengers": {
      "adultCount": 1
    },
    "slice": [
      {
        "origin": "MSP",
        "destination": "ATL",
        "date": "2017-09-01"
      },
      {
        "origin": "ATL",
        "destination": "MSP",
        "date": "2017-09-03"
      }
    ]
  }
}

request = service.trips().search(body=data)
response = request.execute()

# %%
from pprint import pprint

key_func = lambda x : float(x['pricing'][0]['saleTotal'][3:])

price_sorted = sorted(response['trips']['tripOption'], key=key_func)

for option in price_sorted:
    pprint(option['pricing'][0]['saleTotal'])
# Out:
# 'USD189.40'
# 'USD244.60'
# 'USD251.10'
# 'USD274.00'
# 'USD274.00'
# 'USD277.00'
# 'USD278.10'
# 'USD287.60'
# 'USD287.60'
# 'USD287.60'
# 'USD287.60'
# 'USD287.60'
# 'USD287.60'
# 'USD287.60'
# 'USD287.60'
# 'USD287.60'
# 'USD287.60'
# 'USD287.60'
# 'USD287.60'
# 'USD313.60'
# 'USD313.60'
# 'USD313.60'
# 'USD313.60'
# 'USD313.60'
# 'USD313.60'
# 'USD313.60'
# 'USD313.60'
# 'USD313.60'
# 'USD335.70'
# 'USD335.70'
# 'USD339.80'
# 'USD343.60'
# 'USD343.60'
# 'USD343.60'
# 'USD357.60'
# 'USD357.60'
# 'USD357.60'
# 'USD357.60'
# 'USD361.55'
# 'USD361.55'
# 'USD365.65'
# 'USD379.60'
# 'USD379.60'
# 'USD379.60'
# 'USD379.60'
# 'USD379.60'
# 'USD379.60'
# 'USD379.60'
# 'USD379.60'
# 'USD379.60'
# 'USD379.60'
# 'USD379.60'
# 'USD379.60'
# 'USD383.60'
# 'USD383.60'
# 'USD383.60'
# 'USD405.70'
# 'USD405.70'
# 'USD405.70'
# 'USD405.70'
# 'USD405.70'
# 'USD405.70'
# 'USD405.70'
# 'USD405.70'
# 'USD405.70'
# 'USD405.70'
# 'USD405.70'
# 'USD408.60'
# 'USD408.60'
# 'USD411.60'
# 'USD411.60'
# ...
